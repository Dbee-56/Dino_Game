# %%
# !pip install pytesseract

# %%
# !pip install mss pydirectinput

# %%
# MSS used for screen capture
from mss import mss
# pydirect used for sending comands
import pydirectinput
import cv2
import numpy as np
# for ocr
import pytesseract
from matplotlib import pyplot as plt
import time
# enviroment component
from gym import Env
from gym.spaces import Box,Discrete

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# ### Creating Custom Enviroment

# %%
class WebGame(Env):
    def __init__(self):
        super().__init__()
        #setup space
        self.observation_space=Box(low=0,high=255,shape=(1,83,100),dtype=np.uint8)
        self.action_space=Discrete(3)
        # define extraction parameter
        self.cap=mss()
        self.game_location={'top':300,'left':0,'width':600,'height':500}
        self.game_done={'top':405,'left':630,'width':660,'height':100}
        
        pass
    def step(self,action):
        action_map={
            0:'space',
            1:'down',
            2:'no_op'
        }
        if action !=2:
            pydirectinput.press(action_map[action])
        
        #checking whether the game is done
        done,done_cap=self.get_done()
        #get the next observation
        new_observation=self.get_observation()
        #reward
        if done==True:
            reward=-4
        else:
            reward=2
        #info
        info={}
        
        return new_observation,reward,done,info
        
        pass
    def render(self):
        cv2.imshow('Game',np.array(self.cap.grab(self.game_location))[:,:,:3])
        if cv2.waitKey(1) & 0xFF==ord('q'):
            self.close()
            
    def reset(self):
        time.sleep(1)
        pydirectinput.click(x=150,y=150)
        pydirectinput.press('space')
        return self.get_observation()
    
    def close(self):
        cv2.destroyAllWindows()
    
    # get the part of the observation of the game we want
    def get_observation(self):
        #Get screen
        raw=np.array(self.cap.grab(self.game_location))[:,:,:3]
        #Grayscale
        gray=cv2.cvtColor(raw,cv2.COLOR_BGR2GRAY)
        #resize
        resized=cv2.resize(gray,(100,83))
        #Add channel first
        channel=np.reshape(resized,(1,83,100))
        return channel        
    #get done
    def get_done(self):
        done_cap=np.array(self.cap.grab(self.game_done))[:,:,:3]
        #valid done text
        done_strings=['G A M E','G A H E','Go A']
        
        #Apply OCR
        done=False
        res=pytesseract.image_to_string(done_cap)[:4]
        if res in done_strings:
            done=True
        
        return done,done_cap

# %%
env=WebGame()

# %%
env.reset()
# Out:
# array([[[33, 33, 33, ..., 33, 33, 33],
#         [33, 33, 33, ..., 33, 33, 33],
#         [33, 33, 33, ..., 33, 33, 33],
#         ...,
#         [33, 33, 33, ..., 33, 33, 33],
#         [33, 33, 33, ..., 33, 33, 33],
#         [33, 33, 33, ..., 33, 33, 33]]], dtype=uint8)

# %%
plt.imshow(env.get_observation()[0])

# %%
done,done_cap=env.get_done()

# %%
done
# Out:
# True

# %%
plt.imshow(done_cap)

# %% [markdown]
# ### Testing Enviroment

# %%
env=WebGame()

# %%
obs=env.get_observation()[0]

# %%
plt.imshow(cv2.cvtColor(obs,cv2.COLOR_BGR2RGB))

# %%
done,done_cap=env.get_done()

# %%
print(done)
# Out:
# True

# %%
plt.imshow(done_cap)

# %%
for episode in range(5):
    obs=env.reset()
    done=False
    score=0
    
    while not done:
        obs,reward,done,info=env.step(env.action_space.sample())
        score+=reward
    print(f'Score for episode {episode} is {score}')
# Out:
# Score for episode 0 is 14
# Score for episode 1 is 10
# Score for episode 2 is 9
# Score for episode 3 is 11
# Score for episode 4 is 10

# %% [markdown]
# ### Train the model

# %%
import os
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self,check_freq,save_path,verbose=1):
        super(TrainAndLoggingCallback,self).__init__(verbose)
        self.check_freq=check_freq
        self.save_path=save_path
    
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path,exist_ok=True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq==0:
            model_path=os.path.join(self.save_path,'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

# %%
CHECKPOINT_DIR='./Train/'
LOG_DIR='./Logs/'

# %%
callback=TrainAndLoggingCallback(check_freq=1000,save_path=CHECKPOINT_DIR)

# %%
from stable_baselines3 import DQN

# %%
model=DQN('CnnPolicy',env,tensorboard_log=LOG_DIR,verbose=1,
          buffer_size=200000,learning_starts=1000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model=DQN.load(os.path.join('Train2','best_model_58000'),env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model

# %%
model.learn(total_timesteps=100000,callback=callback)
# Out:
# Logging to ./Logs/DQN_17
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10       |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 40       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.1     |
# |    ep_rew_mean      | 14.2     |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 81       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 14.7     |
# ...

# %% [markdown]
# ### Testing

# %%
os.path.join('Train','best_model_88000')
# Out:
# 'Train\\best_model_88000'

# %%
model_test=DQN.load(os.path.join('Train','best_model_69000'),env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
for episode in range(5):
    obs=env.reset()
    done=False  
    score=0
    
    while not done:
        action,_=model.predict(obs)
        obs,reward,done,info=env.step(env.action_space.sample())
        score+=reward
    print(f'Score for episode {episode} is {score}')
# Out:
# Score for episode 0 is -4
# Score for episode 1 is -4
# Score for episode 2 is 12
# Score for episode 3 is 18
# Score for episode 4 is 18

# %%
model.save('latest')

# %%
model_test=DQN.load(os.path.join('Train','best_model_80000'))
